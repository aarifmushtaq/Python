# %% [markdown]
# <a href="https://colab.research.google.com/github/aarifmushtaq/Python/blob/main/Python_Basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello World!")
# Out:
# Hello World!

# %%
print("Hello",1,4,5,True)
print("Hello 1 4 5 ")
# Out:
# Hello 1 4 5 True
# Hello 1 4 5

# %%
print("Hello","World",sep="-")
# Out:
# Hello-World

# %%
print("Hello","world",end="5")
# Out:
# Hello world5

# %%
type([2,3,4,])
# Out:
# list

# %%
a=5
b=-7
print(a+b)
# Out:
# False -2

# %%
#Dynamic Typing
a=5 #Here We Dont Mention The Datatype
#static Typing
#int b=5 python do not ssupport this


b,c,d=4,5,6
print(a,b,c,d)
# Out:
# 5 4 5 6

# %%
x=input("Enter anything ")
print("You Have Entered ",x)
print(type(x))

y=input("Enter Any Number: ")
print("You Have Entered ",y)
print(type(y))

z=int(input("Enter Any Number: "))
print("You Have Entered ",z)
print(type(z))
# Out:
# Enter anything Python
# You Have Entered  Python
# <class 'str'>
# Enter Any Number: 3
# You Have Entered  3
# <class 'str'>
# Enter Any Number: 7
# You Have Entered  7
# <class 'int'>

# %%
#Print Function

name=input("Enter Your Name: ")
print(f"Hello {name}")
# Out:
# Enter Your Name: Aarif Mushtaq
# Hello Aarif Mushtaq
